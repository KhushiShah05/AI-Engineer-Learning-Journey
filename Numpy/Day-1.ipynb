# %% [markdown]
# <a href="https://colab.research.google.com/github/KhushiShah05/AI-Engineer-Learning-Journey/blob/main/Numpy/Day-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Numerical python
# this liabrary used for :
# -Araays
# -Mathematics
# -Statistics
# -Matrix Operation
# -Data science
# -ML
# python list is good for small tasks
# but for large calculations you need numpy

# %%
import numpy as np
arr = np.array([10,20,30,40])
print(arr)
print(arr[1])
# Out:
# [10 20 30 40]
# 20

# %% [markdown]
# Challenge-1

# %%
arr = ([5,10,15,20,25])
print(arr)
# Out:
# [5, 10, 15, 20, 25]

# %% [markdown]
# Challenge-2

# %%
arr = ([100,200,300,400])
print(arr[1])
# Out:
# 200

# %% [markdown]
# Challenge-3

# %%
arr =np.array([1,2,3,4,5])
res = arr + 5
print(res)
# Out:
# [ 6  7  8  9 10]

# %% [markdown]
# challenge-4

# %%
arr = np.array([2,4,6,8])
res = arr * 3
print(res)
# Out:
# [ 6 12 18 24]
